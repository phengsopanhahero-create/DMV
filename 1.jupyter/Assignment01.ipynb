# %% [markdown]
# # Group 11

# %% [markdown]
# # Assignment 01

# %% [markdown]
# # 1. Creating heading

# %% [markdown]
# # Hello what's up

# %% [markdown]
# ## Hello what's up

# %% [markdown]
# ### Hello what's up

# %% [markdown]
# # 2. Creating List

# %% [markdown]
# Numbering List
# 1. Apple
# 2. Banana
# 3. Watermelon

# %% [markdown]
# Bullet List
# - Apple
# - Banana
# - Watermelon

# %% [markdown]
# # 3. Formatting Text

# %% [markdown]
# **Bold text**

# %% [markdown]
# *Italic text*

# %% [markdown]
# # 4. Highlight code

# %% [markdown]
# `Here is some code!`

# %% [markdown]
# # 5. Coloring Text

# %% [markdown]
# <span style="color:red">Red</span>,
# <span style="color:green">green</span> and
# <span style="color:blue">blue</span>.

# %% [markdown]
# # 6. Using Hyperlink

# %% [markdown]
# `print()` is a [function](https://docs.python.org/3/library/functions.html) in python.

# %% [markdown]
# # 7. Display Image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. Writing and Running Code

# %%
print("Welcome to jupyter notebook")
# Out:
# Welcome to jupyter notebook
